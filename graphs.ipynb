# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# 📊 Import libraries
import re
import matplotlib.pyplot as plt

# 📂 Load your log file (Assume it's named 'train_log.txt' and uploaded to Kaggle Notebook)
log_path = '/kaggle/input/rcnnfeatureextractlog/rcnnnotebook.log'

# ⬇️ Initialize storage
epochs = []
train_losses = []
valid_losses = []
accuracies = []
norm_eds = []
print("RCNN")

# 📖 Regex patterns
epoch_info_pattern = re.compile(r'Epoch: \[(\d+)/\d+\]')
loss_info_pattern = re.compile(r'Train loss: ([0-9.]+), Valid loss: ([0-9.]+)')
acc_info_pattern = re.compile(r'Current_accuracy *: *([0-9.]+), Current_norm_ED *: *([0-9.]+)')

# 📋 Parse log file
with open(log_path, 'r') as file:
    lines = file.readlines()
    current_epoch = None

    for line in lines:
        # Extract epoch number
        epoch_match = epoch_info_pattern.search(line)
        if epoch_match:
            current_epoch = int(epoch_match.group(1))

        # Extract train & valid loss
        loss_match = loss_info_pattern.search(line)
        if loss_match and current_epoch is not None:
            train_loss = float(loss_match.group(1))
            valid_loss = float(loss_match.group(2))
            train_losses.append(train_loss)
            valid_losses.append(valid_loss)
            epochs.append(current_epoch)

        # Extract accuracy & norm_ED
        acc_match = acc_info_pattern.search(line)
        if acc_match:
            accuracy = float(acc_match.group(1))
            norm_ed = float(acc_match.group(2))
            accuracies.append(accuracy)
            norm_eds.append(norm_ed)

# ✅ Sanity check
print(f'Total epochs parsed: {len(epochs)}')
print(f'First 5 epochs: {epochs[:5]}')
print(f'First 5 train losses: {train_losses[:5]}')
print(f'First 5 accuracies: {accuracies[:5]}')

# 📈 Plot 1: Accuracy vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(accuracies))
plt.plot(epochs[:min_len], accuracies[:min_len], marker='o', color='blue')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()


# 📈 Plot 2: Norm_ED vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(norm_eds))
plt.plot(epochs[:min_len], norm_eds[:min_len], marker='o', color='green')
plt.title('Norm_ED vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm_ED')
plt.grid(True)
plt.show()

# 📈 Plot 3: Train & Valid Loss vs Epoch
plt.figure(figsize=(8,5))
min_len_train = min(len(epochs), len(train_losses))
min_len_valid = min(len(epochs), len(valid_losses))
plt.plot(epochs[:min_len_train], train_losses[:min_len_train], marker='o', label='Train Loss', color='red')
plt.plot(epochs[:min_len_valid], valid_losses[:min_len_valid], marker='o', label='Valid Loss', color='orange')
plt.title('Train & Valid Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# RCNN
# Total epochs parsed: 142
# First 5 epochs: [0, 1, 2, 3, 4]
# First 5 train losses: [2.70386, 2.31067, 1.98863, 1.66884, 1.40976]
# First 5 accuracies: [0.0, 14.49, 23.936, 26.843, 40.225]

# %%
# 📊 Import libraries
import re
import matplotlib.pyplot as plt

# 📂 Load your log file (Assume it's named 'train_log.txt' and uploaded to Kaggle Notebook)
log_path = '/kaggle/input/resnetfeatureextractlog/logsofbettermodel.log'
print("resnet")
# ⬇️ Initialize storage
epochs = []
train_losses = []
valid_losses = []
accuracies = []
norm_eds = []

# 📖 Regex patterns
epoch_info_pattern = re.compile(r'Epoch: \[(\d+)/\d+\]')
loss_info_pattern = re.compile(r'Train loss: ([0-9.]+), Valid loss: ([0-9.]+)')
acc_info_pattern = re.compile(r'Current_accuracy *: *([0-9.]+), Current_norm_ED *: *([0-9.]+)')

# 📋 Parse log file
with open(log_path, 'r') as file:
    lines = file.readlines()
    current_epoch = None

    for line in lines:
        # Extract epoch number
        epoch_match = epoch_info_pattern.search(line)
        if epoch_match:
            current_epoch = int(epoch_match.group(1))

        # Extract train & valid loss
        loss_match = loss_info_pattern.search(line)
        if loss_match and current_epoch is not None:
            train_loss = float(loss_match.group(1))
            valid_loss = float(loss_match.group(2))
            train_losses.append(train_loss)
            valid_losses.append(valid_loss)
            epochs.append(current_epoch)

        # Extract accuracy & norm_ED
        acc_match = acc_info_pattern.search(line)
        if acc_match:
            accuracy = float(acc_match.group(1))
            norm_ed = float(acc_match.group(2))
            accuracies.append(accuracy)
            norm_eds.append(norm_ed)

# ✅ Sanity check
print(f'Total epochs parsed: {len(epochs)}')
print(f'First 5 epochs: {epochs[:5]}')
print(f'First 5 train losses: {train_losses[:5]}')
print(f'First 5 accuracies: {accuracies[:5]}')

# 📈 Plot 1: Accuracy vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(accuracies))
plt.plot(epochs[:min_len], accuracies[:min_len], marker='o', color='blue')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()


# 📈 Plot 2: Norm_ED vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(norm_eds))
plt.plot(epochs[:min_len], norm_eds[:min_len], marker='o', color='green')
plt.title('Norm_ED vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm_ED')
plt.grid(True)
plt.show()

# 📈 Plot 3: Train & Valid Loss vs Epoch
plt.figure(figsize=(8,5))
min_len_train = min(len(epochs), len(train_losses))
min_len_valid = min(len(epochs), len(valid_losses))
plt.plot(epochs[:min_len_train], train_losses[:min_len_train], marker='o', label='Train Loss', color='red')
plt.plot(epochs[:min_len_valid], valid_losses[:min_len_valid], marker='o', label='Valid Loss', color='orange')
plt.title('Train & Valid Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# resnet
# Total epochs parsed: 166
# First 5 epochs: [0, 1, 2, 3, 4]
# First 5 train losses: [2.42664, 1.85903, 1.34445, 0.9092, 0.6351]
# First 5 accuracies: [0.0, 8.819, 30.249, 32.209, 42.859]

# %%
# 📊 Import libraries
import re
import matplotlib.pyplot as plt

# 📂 Load your log file (Assume it's named 'train_log.txt' and uploaded to Kaggle Notebook)
log_path = '/kaggle/input/vitfeatureextractlog/vitHTRlogs.txt'
print("vit")
# ⬇️ Initialize storage
epochs = []
train_losses = []
valid_losses = []
accuracies = []
norm_eds = []

# 📖 Regex patterns
epoch_info_pattern = re.compile(r'Epoch: \[(\d+)/\d+\]')
loss_info_pattern = re.compile(r'Train loss: ([0-9.]+), Valid loss: ([0-9.]+)')
acc_info_pattern = re.compile(r'Current_accuracy *: *([0-9.]+), Current_norm_ED *: *([0-9.]+)')

# 📋 Parse log file
with open(log_path, 'r') as file:
    lines = file.readlines()
    current_epoch = None

    for line in lines:
        # Extract epoch number
        epoch_match = epoch_info_pattern.search(line)
        if epoch_match:
            current_epoch = int(epoch_match.group(1))

        # Extract train & valid loss
        loss_match = loss_info_pattern.search(line)
        if loss_match and current_epoch is not None:
            train_loss = float(loss_match.group(1))
            valid_loss = float(loss_match.group(2))
            train_losses.append(train_loss)
            valid_losses.append(valid_loss)
            epochs.append(current_epoch)

        # Extract accuracy & norm_ED
        acc_match = acc_info_pattern.search(line)
        if acc_match:
            accuracy = float(acc_match.group(1))
            norm_ed = float(acc_match.group(2))
            accuracies.append(accuracy)
            norm_eds.append(norm_ed)

# ✅ Sanity check
print(f'Total epochs parsed: {len(epochs)}')
print(f'First 5 epochs: {epochs[:5]}')
print(f'First 5 train losses: {train_losses[:5]}')
print(f'First 5 accuracies: {accuracies[:5]}')

# 📈 Plot 1: Accuracy vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(accuracies))
plt.plot(epochs[:min_len], accuracies[:min_len], marker='o', color='blue')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()


# 📈 Plot 2: Norm_ED vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(norm_eds))
plt.plot(epochs[:min_len], norm_eds[:min_len], marker='o', color='green')
plt.title('Norm_ED vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm_ED')
plt.grid(True)
plt.show()

# 📈 Plot 3: Train & Valid Loss vs Epoch
plt.figure(figsize=(8,5))
min_len_train = min(len(epochs), len(train_losses))
min_len_valid = min(len(epochs), len(valid_losses))
plt.plot(epochs[:min_len_train], train_losses[:min_len_train], marker='o', label='Train Loss', color='red')
plt.plot(epochs[:min_len_valid], valid_losses[:min_len_valid], marker='o', label='Valid Loss', color='orange')
plt.title('Train & Valid Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# vit
# Total epochs parsed: 105
# First 5 epochs: [0, 1, 2, 3, 4]
# First 5 train losses: [2.77801, 2.6194, 2.5435, 2.48245, 2.4278]
# First 5 accuracies: [0.0, 8.064, 11.213, 12.675, 13.912]

# %%
# 📊 Import libraries
import re
import matplotlib.pyplot as plt

# 📂 Load your log file (Assume it's named 'train_log.txt' and uploaded to Kaggle Notebook)
log_path = '/kaggle/input/vggfeatureextractionlog/attentionhtrbysaikaustav.log'
print("vit")
# ⬇️ Initialize storage
epochs = []
train_losses = []
valid_losses = []
accuracies = []
norm_eds = []

# 📖 Regex patterns
epoch_info_pattern = re.compile(r'Epoch: \[(\d+)/\d+\]')
loss_info_pattern = re.compile(r'Train loss: ([0-9.]+), Valid loss: ([0-9.]+)')
acc_info_pattern = re.compile(r'Current_accuracy *: *([0-9.]+), Current_norm_ED *: *([0-9.]+)')

# 📋 Parse log file
with open(log_path, 'r') as file:
    lines = file.readlines()
    current_epoch = None

    for line in lines:
        # Extract epoch number
        epoch_match = epoch_info_pattern.search(line)
        if epoch_match:
            current_epoch = int(epoch_match.group(1))

        # Extract train & valid loss
        loss_match = loss_info_pattern.search(line)
        if loss_match and current_epoch is not None:
            train_loss = float(loss_match.group(1))
            valid_loss = float(loss_match.group(2))
            train_losses.append(train_loss)
            valid_losses.append(valid_loss)
            epochs.append(current_epoch)

        # Extract accuracy & norm_ED
        acc_match = acc_info_pattern.search(line)
        if acc_match:
            accuracy = float(acc_match.group(1))
            norm_ed = float(acc_match.group(2))
            accuracies.append(accuracy)
            norm_eds.append(norm_ed)

# ✅ Sanity check
print(f'Total epochs parsed: {len(epochs)}')
print(f'First 5 epochs: {epochs[:5]}')
print(f'First 5 train losses: {train_losses[:5]}')
print(f'First 5 accuracies: {accuracies[:5]}')

# 📈 Plot 1: Accuracy vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(accuracies))
plt.plot(epochs[:min_len], accuracies[:min_len], marker='o', color='blue')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()


# 📈 Plot 2: Norm_ED vs Epoch
plt.figure(figsize=(8,5))
min_len = min(len(epochs), len(norm_eds))
plt.plot(epochs[:min_len], norm_eds[:min_len], marker='o', color='green')
plt.title('Norm_ED vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Norm_ED')
plt.grid(True)
plt.show()

# 📈 Plot 3: Train & Valid Loss vs Epoch
plt.figure(figsize=(8,5))
min_len_train = min(len(epochs), len(train_losses))
min_len_valid = min(len(epochs), len(valid_losses))
plt.plot(epochs[:min_len_train], train_losses[:min_len_train], marker='o', label='Train Loss', color='red')
plt.plot(epochs[:min_len_valid], valid_losses[:min_len_valid], marker='o', label='Valid Loss', color='orange')
plt.title('Train & Valid Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# vit
# Total epochs parsed: 83
# First 5 epochs: [0, 1, 2, 3, 4]
# First 5 train losses: [2.66118, 2.38083, 2.20131, 2.05071, 1.89591]
# First 5 accuracies: [0.0, 3.647, 8.177, 11.582, 10.249]
